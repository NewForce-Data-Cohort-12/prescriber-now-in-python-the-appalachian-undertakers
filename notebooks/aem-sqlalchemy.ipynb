# %% [markdown]
# # Install dependencies

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\student\anaconda3\lib\site-packages (2.9.11)

# %% [markdown]
# # Import dependencies

# %%
from sqlalchemy import create_engine, text

# %%
import pandas as pd

# %% [markdown]
# # Connect to prescribers database

# %%
database_name = 'prescribers'    # Fill this in with your prescribers database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %% [markdown]
# ## Create engine

# %%
engine = create_engine(connection_string)

# %% [markdown]
# # Queries

# %% [markdown]
# ## Utils

# %%
## Read SQL file
def sql(path):
    try:
        with open(path, "r", encoding="utf-8") as file:
            return file.read()
    except FileNotFoundError:
        print("Error: SQL file not found.")
        raise
    except Exception as e:
        print(f"Error reading SQL file: {e}")
        raise

# %% [markdown]
# ## Main

# %%
query = sql("queries/distinct_generic_drugs.sql")

# %%
with engine.connect() as connection:
    people = pd.read_sql(text(query), con = connection)

people.head()
# Out:
#                      generic_name opioid_drug_flag  \
# 0                      PREGABALIN                N
# 1                       MINOXIDIL                N
# 2     EMPAGLIFLOZIN/METFORMIN HCL                N
# 3             CLEMASTINE FUMARATE                N
# 4  NEOMYCIN/POLYMYXN B/GRAMICIDIN                N
#
#   long_acting_opioid_drug_flag antibiotic_drug_flag antipsychotic_drug_flag
# 0                            N                    N                       N
# 1                            N                    N                       N
# 2                            N                    N                       N
# 3                            N                    N                       N
# 4                            N                    N                       N

# %% [markdown]
# For much more information about SQLAlchemy and to see a more “Pythonic” way to execute queries, see Introduction to Databases in Python: https://www.datacamp.com/courses/introduction-to-relational-databases-in-python
